# %%
import numpy as np
import pylab as plt
import matplotlib
import numpy as np
import sqlite3 as sqlite
import os
import trace_rect_mat

# %matplotlib inline
font = {        'size'   : 16}
matplotlib.rc('font', **font)

# %%
plt.figure(figsize=(15,5))
trace_rect_mat.trace_rect()
# Out:
# input shape:  (16, 2048)
# [[ -8.31964822e-07   1.10053104e-03  -6.08278447e-02]
#  [ -6.29304959e-08   3.64241155e-04   2.93982790e-02]
#  [ -8.86951759e-07   1.06630315e-03  -1.48793128e-02]
#  [  9.41959399e-07  -6.75790814e-04   2.30494670e-01]]

# %%
a = np.load('s150905_c003___infl_Kbb_035_trace.npy')
b = a.item(0)

# %%
# (tfit,sampleLoc,peakLoc,lineProfile, fitParams, spectrum)
plt.figure(figsize=(15,8))
s = 'slice1'
lineprofile = b[s][3]

plt.subplot(3,1,1)
plt.plot(b[s][-1])
plt.subplot(3,1,2)
plt.plot(b[s][2])
plt.subplot(3,1,3)
plt.plot(lineprofile[:,1000])
print np.shape(lineprofile)
# Out:
# (16, 2048)
